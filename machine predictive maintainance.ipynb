# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sweetviz as sv

# %%
df=pd.read_csv("predictive_maintenance.csv")
df
# Out:
#         UDI Product ID Type  Air temperature [K]  Process temperature [K]  \
# 0         1     M14860    M                298.1                    308.6
# 1         2     L47181    L                298.2                    308.7
# 2         3     L47182    L                298.1                    308.5
# 3         4     L47183    L                298.2                    308.6
# 4         5     L47184    L                298.2                    308.7
# ...     ...        ...  ...                  ...                      ...
# 9995   9996     M24855    M                298.8                    308.4
# 9996   9997     H39410    H                298.9                    308.4
# 9997   9998     M24857    M                299.0                    308.6
# 9998   9999     H39412    H                299.0                    308.7
# 9999  10000     M24859    M                299.0                    308.7
#
#       Rotational speed [rpm]  Torque [Nm]  Tool wear [min]  Target  \
# ...

# %%
report=sv.analyze(df)
# Out:
# Done! Use 'show' commands to display/save.   |██████████| [100%]   00:00 -> (00:00 left)

# %%
df.columns
# Out:
# Index(['UDI', 'Product ID', 'Type', 'Air temperature [K]',
#        'Process temperature [K]', 'Rotational speed [rpm]', 'Torque [Nm]',
#        'Tool wear [min]', 'Target', 'Failure Type'],
#       dtype='object')

# %%
report.show_html()
# Out:
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
df.head()
# Out:
#    UDI Product ID Type  Air temperature [K]  Process temperature [K]  \
# 0    1     M14860    M                298.1                    308.6
# 1    2     L47181    L                298.2                    308.7
# 2    3     L47182    L                298.1                    308.5
# 3    4     L47183    L                298.2                    308.6
# 4    5     L47184    L                298.2                    308.7
#
#    Rotational speed [rpm]  Torque [Nm]  Tool wear [min]  Target Failure Type
# 0                    1551         42.8                0       0   No Failure
# 1                    1408         46.3                3       0   No Failure
# 2                    1498         49.4                5       0   No Failure
# 3                    1433         39.5                7       0   No Failure
# 4                    1408         40.0                9       0   No Failure

# %%
df.shape
# Out:
# (10000, 10)

# %%
df.isnull()
# Out:
#         UDI  Product ID   Type  Air temperature [K]  Process temperature [K]  \
# 0     False       False  False                False                    False
# 1     False       False  False                False                    False
# 2     False       False  False                False                    False
# 3     False       False  False                False                    False
# 4     False       False  False                False                    False
# ...     ...         ...    ...                  ...                      ...
# 9995  False       False  False                False                    False
# 9996  False       False  False                False                    False
# 9997  False       False  False                False                    False
# 9998  False       False  False                False                    False
# 9999  False       False  False                False                    False
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   UDI                      10000 non-null  int64
#  1   Product ID               10000 non-null  object
#  2   Type                     10000 non-null  object
#  3   Air temperature [K]      10000 non-null  float64
#  4   Process temperature [K]  10000 non-null  float64
#  5   Rotational speed [rpm]   10000 non-null  int64
#  6   Torque [Nm]              10000 non-null  float64
#  7   Tool wear [min]          10000 non-null  int64
#  8   Target                   10000 non-null  int64
#  9   Failure Type             10000 non-null  object
# dtypes: float64(3), int64(4), object(3)
# memory usage: 781.4+ KB

# %%
df.isnull().sum()
# Out:
# UDI                        0
# Product ID                 0
# Type                       0
# Air temperature [K]        0
# Process temperature [K]    0
# Rotational speed [rpm]     0
# Torque [Nm]                0
# Tool wear [min]            0
# Target                     0
# Failure Type               0
# dtype: int64

# %%
df.describe()
# Out:
#                UDI  Air temperature [K]  Process temperature [K]  \
# count  10000.00000         10000.000000             10000.000000
# mean    5000.50000           300.004930               310.005560
# std     2886.89568             2.000259                 1.483734
# min        1.00000           295.300000               305.700000
# 25%     2500.75000           298.300000               308.800000
# 50%     5000.50000           300.100000               310.100000
# 75%     7500.25000           301.500000               311.100000
# max    10000.00000           304.500000               313.800000
#
#        Rotational speed [rpm]   Torque [Nm]  Tool wear [min]        Target
# count            10000.000000  10000.000000     10000.000000  10000.000000
# mean              1538.776100     39.986910       107.951000      0.033900
# std                179.284096      9.968934        63.654147      0.180981
# min               1168.000000      3.800000         0.000000      0.000000
# ...

# %%
cols=['Target','UDI']
df.drop(cols,axis=1)
# Out:
#      Product ID Type  Air temperature [K]  Process temperature [K]  \
# 0        M14860    M                298.1                    308.6
# 1        L47181    L                298.2                    308.7
# 2        L47182    L                298.1                    308.5
# 3        L47183    L                298.2                    308.6
# 4        L47184    L                298.2                    308.7
# ...         ...  ...                  ...                      ...
# 9995     M24855    M                298.8                    308.4
# 9996     H39410    H                298.9                    308.4
# 9997     M24857    M                299.0                    308.6
# 9998     H39412    H                299.0                    308.7
# 9999     M24859    M                299.0                    308.7
#
#       Rotational speed [rpm]  Torque [Nm]  Tool wear [min] Failure Type
# 0                       1551         42.8                0   No Failure
# ...

# %%
df.duplicated(subset=None, keep='first')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Length: 10000, dtype: bool

# %%
plt.bar(df['Failure Type'], df['Torque [Nm]'], color ='black', width = 0.2)
plt.xlabel('failure type')
plt.ylabel('torque')
plt.rcParams["figure.figsize"] = (20,6)
plt.show()

# %%
a=df['Air temperature [K]']
b=df['Process temperature [K]']
X=df['Failure Type']
ax=plt.subplot(111)
ax.bar(X, a, width=0.2)
ax.bar(X,b,width=0.1,color='red',align='edge')

plt.show()

# %%
df.hist(['Type','Air temperature [K]','Process temperature [K]','Rotational speed [rpm]','Torque [Nm]','Tool wear [min]',
         'Target','Failure Type'],figsize=(18,10))
# Out:
# array([[<Axes: title={'center': 'Air temperature [K]'}>,
#         <Axes: title={'center': 'Process temperature [K]'}>],
#        [<Axes: title={'center': 'Rotational speed [rpm]'}>,
#         <Axes: title={'center': 'Torque [Nm]'}>],
#        [<Axes: title={'center': 'Tool wear [min]'}>,
#         <Axes: title={'center': 'Target'}>]], dtype=object)

# %%
columns=['Type','Air temperature [K]','Process temperature [K]','Rotational speed [rpm]','Tool wear [min]','Failure Type']
for a in columns:
    df.plot.scatter(x=a,y='Torque [Nm]',figsize=(13,5),title=a+' vs '+'Torque [Nm]')

# %%
import seaborn as sns

# %%
hm =df[[ 'Air temperature [K]',
       'Process temperature [K]', 'Rotational speed [rpm]', 'Torque [Nm]',
       'Tool wear [min]', 'Target']]
#hm =df.drop(['Product ID','Failure Type','Type'],axis=1,inplace=True)
sns.heatmap(hm.corr(), cmap="YlGnBu", annot=True);
plt.show()

# %%
df.columns
# Out:
# Index(['UDI', 'Product ID', 'Type', 'Air temperature [K]',
#        'Process temperature [K]', 'Rotational speed [rpm]', 'Torque [Nm]',
#        'Tool wear [min]', 'Target', 'Failure Type'],
#       dtype='object')

# %%
x= df.drop(["UDI","Target","Type","Product ID","Failure Type"],axis=1)
y=df["Failure Type"]
from sklearn.model_selection import train_test_split
x_train, x_test,y_train, y_test = train_test_split(x,y, test_size=0.30, random_state=1)

# %%
x.columns
# Out:
# Index(['Air temperature [K]', 'Process temperature [K]',
#        'Rotational speed [rpm]', 'Torque [Nm]', 'Tool wear [min]'],
#       dtype='object')

# %%
from sklearn.preprocessing import StandardScaler  
sc = StandardScaler()  
x_train = sc.fit_transform(x_train)  
x_test = sc.transform(x_test)

# %%
from sklearn.naive_bayes import GaussianNB  
classifier = GaussianNB()  
classifier.fit(x_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred=classifier.predict(x_test)
y_pred
# Out:
# array(['No Failure', 'No Failure', 'No Failure', ..., 'No Failure',
#        'No Failure', 'No Failure'], dtype='<U24')

# %%
y_test
# Out:
# 9953    No Failure
# 3850    No Failure
# 4962    No Failure
# 3886    No Failure
# 5437    No Failure
#            ...
# 5273    No Failure
# 8014    No Failure
# 8984    No Failure
# 6498    No Failure
# 6327    No Failure
# Name: Failure Type, Length: 3000, dtype: object

# %%
classifier.score(x_test,y_test)
# Out:
# 0.9513333333333334

# %%
from sklearn.metrics import confusion_matrix,classification_report  
print(confusion_matrix(y_test, y_pred),sep="\n")
# Out:
# [[  23    6    2    0    0    0]
#  [  38 2800   11   41    0    0]
#  [   1    5   21    0    0    0]
#  [   4   17    2   10    0    0]
#  [   1    7    0    0    0    0]
#  [   0   10    1    0    0    0]]

# %%
a=classification_report(y_test,y_pred)
print(f"cllasification_report:\n{a}")
import warnings
warnings.filterwarnings('ignore')
# Out:
# cllasification_report:
#                           precision    recall  f1-score   support
#
# Heat Dissipation Failure       0.34      0.74      0.47        31
#               No Failure       0.98      0.97      0.98      2890
#       Overstrain Failure       0.57      0.78      0.66        27
#            Power Failure       0.20      0.30      0.24        33
#          Random Failures       0.00      0.00      0.00         8
#        Tool Wear Failure       0.00      0.00      0.00        11
#
#                 accuracy                           0.95      3000
#                macro avg       0.35      0.47      0.39      3000
#             weighted avg       0.96      0.95      0.95      3000
# c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
x_train.shape,x_test.shape
# Out:
# ((7000, 5), (3000, 5))

# %%
y_train.shape,y_test.shape
# Out:
# ((7000,), (3000,))

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
from sklearn import tree

# %%
clf_gini = DecisionTreeClassifier(criterion='gini',max_depth=3,random_state=10)
clf_gini.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=10)

# %%
plt.figure(figsize=(12,8))
tree.plot_tree(clf_gini.fit(x_train,y_train))
# Out:
# [Text(0.5, 0.875, 'x[3] <= 2.257\ngini = 0.067\nsamples = 7000\nvalue = [81, 6762, 51, 62, 10, 34]'),
#  Text(0.25, 0.625, 'x[3] <= -2.7\ngini = 0.054\nsamples = 6923\nvalue = [74, 6734, 43, 28, 10, 34]'),
#  Text(0.125, 0.375, 'x[0] <= 2.026\ngini = 0.18\nsamples = 20\nvalue = [0, 2, 0, 18, 0, 0]'),
#  Text(0.0625, 0.125, 'gini = 0.1\nsamples = 19\nvalue = [0, 1, 0, 18, 0, 0]'),
#  Text(0.1875, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.375, 0.375, 'x[2] <= -0.89\ngini = 0.049\nsamples = 6903\nvalue = [74, 6732, 43, 10, 10, 34]'),
#  Text(0.3125, 0.125, 'gini = 0.223\nsamples = 902\nvalue = [74, 791, 34, 0, 2, 1]'),
#  Text(0.4375, 0.125, 'gini = 0.02\nsamples = 6001\nvalue = [0, 5941, 9, 10, 8, 33]'),
#  Text(0.75, 0.625, 'x[3] <= 2.811\ngini = 0.654\nsamples = 77\nvalue = [7, 28, 8, 34, 0, 0]'),
#  Text(0.625, 0.375, 'x[2] <= -0.963\ngini = 0.667\nsamples = 54\nvalue = [7, 26, 7, 14, 0, 0]'),
# ...

# %%
y_pred_gini=clf_gini.predict(x_train)
y_pred_gini
# Out:
# array(['No Failure', 'No Failure', 'No Failure', ..., 'No Failure',
#        'No Failure', 'No Failure'], dtype=object)

# %%
clf_gini.score(x_test,y_test)
# Out:
# 0.97

# %%
a=classification_report(y_test,y_pred)
print(f"cllasification_report:\n{a}")
import warnings
warnings.filterwarnings('ignore')
# Out:
# cllasification_report:
#                           precision    recall  f1-score   support
#
# Heat Dissipation Failure       0.34      0.74      0.47        31
#               No Failure       0.98      0.97      0.98      2890
#       Overstrain Failure       0.57      0.78      0.66        27
#            Power Failure       0.20      0.30      0.24        33
#          Random Failures       0.00      0.00      0.00         8
#        Tool Wear Failure       0.00      0.00      0.00        11
#
#                 accuracy                           0.95      3000
#                macro avg       0.35      0.47      0.39      3000
#             weighted avg       0.96      0.95      0.95      3000

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score

# %%
ndf=df

# %%
ndf.columns
# Out:
# Index(['UDI', 'Product ID', 'Type', 'Air temperature [K]',
#        'Process temperature [K]', 'Rotational speed [rpm]', 'Torque [Nm]',
#        'Tool wear [min]', 'Target', 'Failure Type'],
#       dtype='object')

# %%
A= ndf.drop(["UDI","Target","Type","Product ID","Failure Type"],axis=1)
B=ndf["Failure Type"]

# %%
A_train, A_test, b_train, b_test = train_test_split(A,B, test_size=0.2, random_state=42)

# %%
gb_classifier = GradientBoostingClassifier(n_estimators=100, learning_rate=0.1, max_depth=3, random_state=42)

# %%
gb_classifier.fit(A_train, b_train)
predictions = gb_classifier.predict(A_test)
accuracy = accuracy_score(b_test, predictions)
print(f"Accuracy: {accuracy}")
# Out:
# Accuracy: 0.98

# %%
a=classification_report(b_test,predictions)
print(f"cllasification_report:\n{a}")
import warnings
warnings.filterwarnings('ignore')
# Out:
# cllasification_report:
#                           precision    recall  f1-score   support
#
# Heat Dissipation Failure       0.92      0.80      0.86        15
#               No Failure       0.99      0.99      0.99      1935
#       Overstrain Failure       0.58      0.54      0.56        13
#            Power Failure       0.73      0.80      0.76        20
#          Random Failures       0.00      0.00      0.00         6
#        Tool Wear Failure       0.00      0.00      0.00        11
#
#                 accuracy                           0.98      2000
#                macro avg       0.54      0.52      0.53      2000
#             weighted avg       0.97      0.98      0.98      2000

# %%
import pickle
import os
with open('classifier.pkl','wb')as fileWriteStream:
    pickle.dump(classifier,fileWriteStream)
    fileWriteStream.close()

# %%
with open('gb_classifier.pkl','wb')as fileWriteStream:
    pickle.dump(gb_classifier,fileWriteStream)
    fileWriteStream.close()
